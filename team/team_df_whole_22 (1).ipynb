# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://statiz.sporki.com/stats/?m=team&m2=all&m3=default&so=WAR&ob=DESC&year=2022&sy=&ey=&te=&po=&lt=&reg=&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

team_table = soup.find_all('table')[1]  # 팀 테이블

team_df_whole_22 = pd.read_html(str(team_table))[0]  # 팀 데이터프레임

print("페이지의 팀 기록 데이터프레임:\n")

team_df_whole_22
# Out:
# 페이지의 팀 기록 데이터프레임:
#   Rank Team Unnamed: 2_level_0    정렬▼   WAR▼ WAA (야수)                    \
#   Rank Team Unnamed: 2_level_1    WAR   WAR▼       BT    SB    BR   Def
# 0    1   LG                 22  62.98  62.98     9.15 -0.18  0.45  3.69
# 1    2  SSG                 22  54.16  54.16     2.39 -0.05  0.03  4.99
# 2    3   KT                 22  53.40  53.40    -3.41  0.22  0.29  3.49
# 3    4  KIA                 22  51.39  51.39     8.27  0.25 -0.05  0.60
# 4    5   키움                 22  49.51  49.51    -1.28  0.19 -0.01 -0.11
# 5    6   NC                 22  44.82  44.82    -1.62  0.08  0.37 -1.11
# 6    7   삼성                 22  41.92  41.92    -1.33  0.50 -0.79 -4.73
# 7    8   롯데                 22  39.06  39.06    -1.30 -0.57 -0.20 -6.46
# 8    9   두산                 22  31.72  31.72    -3.19 -0.09 -0.17 -1.48
# 9   10   한화                 22  26.86  26.86    -7.68 -0.34  0.07  1.13
#
#   Rep. Wins Pos. Wins WAA (투수)       Rep. Win (투수)       WAR (투수)
# ...

# %%
# 첫 번째 행을 헤더로 지정하고 데이터프레임을 새로 생성
team_2022_whole = team_df_whole_22.copy()
team_2022_whole.columns = team_2022_whole.columns.get_level_values(1)

# 첫 번째 행 제거
new_df = team_2022_whole.drop([0])

team_2022_whole
# Out:
#    Rank Team  Unnamed: 2_level_1    WAR   WAR▼    BT    SB    BR   Def  \
# 0     1   LG                  22  62.98  62.98  9.15 -0.18  0.45  3.69
# 1     2  SSG                  22  54.16  54.16  2.39 -0.05  0.03  4.99
# 2     3   KT                  22  53.40  53.40 -3.41  0.22  0.29  3.49
# 3     4  KIA                  22  51.39  51.39  8.27  0.25 -0.05  0.60
# 4     5   키움                  22  49.51  49.51 -1.28  0.19 -0.01 -0.11
# 5     6   NC                  22  44.82  44.82 -1.62  0.08  0.37 -1.11
# 6     7   삼성                  22  41.92  41.92 -1.33  0.50 -0.79 -4.73
# 7     8   롯데                  22  39.06  39.06 -1.30 -0.57 -0.20 -6.46
# 8     9   두산                  22  31.72  31.72 -3.19 -0.09 -0.17 -1.48
# 9    10   한화                  22  26.86  26.86 -7.68 -0.34  0.07  1.13
#
#    Rep. Wins  Pos. Wins    GS    GR     GS    GR     GS     GR
# 0       2.42      -0.04  2.80  5.92  12.39  4.31  15.01  10.09
# ...
