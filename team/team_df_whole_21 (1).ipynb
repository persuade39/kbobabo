# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://statiz.sporki.com/stats/?m=team&m2=all&m3=default&so=WAR&ob=DESC&year=2021&sy=&ey=&te=&po=&lt=&reg=&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

team_table = soup.find_all('table')[1]  # 팀 테이블

team_df_whole_21 = pd.read_html(str(team_table))[0]  # 팀 데이터프레임

print("페이지의 팀 기록 데이터프레임:\n")

team_df_whole_21
# Out:
# 페이지의 팀 기록 데이터프레임:
#   Rank Team Unnamed: 2_level_0    정렬▼   WAR▼ WAA (야수)                    \
#   Rank Team Unnamed: 2_level_1    WAR   WAR▼       BT    SB    BR   Def
# 0    1   KT                 21  56.59  56.59     0.03  0.00  0.05  1.62
# 1    2   LG                 21  54.50  54.50     0.69  0.10  0.33  2.25
# 2    3   두산                 21  53.05  53.05     7.36 -0.05  0.09 -1.77
# 3    4  SSG                 21  49.59  49.59     6.92 -0.04  0.17 -1.81
# 4    5   삼성                 21  49.07  49.07    -1.41  0.28 -0.06 -0.60
# 5    6   NC                 21  48.00  48.00     2.99 -0.17 -0.29 -1.49
# 6    7   키움                 21  45.12  45.12    -0.28  0.58  0.07  1.75
# 7    8   롯데                 21  41.84  41.84     2.56 -0.23 -0.08 -2.34
# 8    9  KIA                 21  31.79  31.79    -9.07  0.05 -0.43 -0.42
# 9   10   한화                 21  29.45  29.45    -9.84 -0.51  0.23  2.83
#
#   Rep. Wins Pos. Wins WAA (투수)       Rep. Win (투수)       WAR (투수)
# ...

# %%
# 첫 번째 행을 헤더로 지정하고 데이터프레임을 새로 생성
team_2021_whole = team_df_whole_21.copy()
team_2021_whole.columns = team_2021_whole.columns.get_level_values(1)

# 첫 번째 행 제거
new_df = team_2021_whole.drop([0])

team_2021_whole
# Out:
#    Rank Team  Unnamed: 2_level_1    WAR   WAR▼    BT    SB    BR   Def  \
# 0     1   KT                  21  56.59  56.59  0.03  0.00  0.05  1.62
# 1     2   LG                  21  54.50  54.50  0.69  0.10  0.33  2.25
# 2     3   두산                  21  53.05  53.05  7.36 -0.05  0.09 -1.77
# 3     4  SSG                  21  49.59  49.59  6.92 -0.04  0.17 -1.81
# 4     5   삼성                  21  49.07  49.07 -1.41  0.28 -0.06 -0.60
# 5     6   NC                  21  48.00  48.00  2.99 -0.17 -0.29 -1.49
# 6     7   키움                  21  45.12  45.12 -0.28  0.58  0.07  1.75
# 7     8   롯데                  21  41.84  41.84  2.56 -0.23 -0.08 -2.34
# 8     9  KIA                  21  31.79  31.79 -9.07  0.05 -0.43 -0.42
# 9    10   한화                  21  29.45  29.45 -9.84 -0.51  0.23  2.83
#
#    Rep. Wins  Pos. Wins    GS    GR     GS    GR     GS     GR
# 0       2.33       0.17  6.63  4.97  14.03  3.60  20.45   8.59
# ...
