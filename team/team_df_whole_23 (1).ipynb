# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://statiz.sporki.com/stats/?m=team&m2=all&m3=default&so=WAR&ob=DESC&year=2023&sy=&ey=&te=&po=&lt=&reg=&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

team_table = soup.find_all('table')[1]  # 팀 테이블

team_df_whole_23 = pd.read_html(str(team_table))[0]  # 팀 데이터프레임

print("페이지의 팀 기록 데이터프레임:\n")

team_df_whole_23
# Out:
# 페이지의 팀 기록 데이터프레임:
#   Rank Team Unnamed: 2_level_0    정렬▼   WAR▼ WAA (야수)                    \
#   Rank Team Unnamed: 2_level_1    WAR   WAR▼       BT    SB    BR   Def
# 0    1   LG                 23  59.18  59.18    13.03 -1.30  0.19  0.58
# 1    2   KT                 23  52.24  52.24    -1.20  0.05  0.28  4.30
# 2    3   NC                 23  49.20  49.20     2.83 -0.07 -0.08  1.06
# 3    4  KIA                 23  47.45  47.45     4.89  0.49  0.18  2.74
# 4    5   두산                 23  45.49  45.49    -0.10  0.24 -0.17  1.34
# 5    6  SSG                 23  43.87  43.87    -0.45  0.35 -0.31 -1.44
# 6    7   롯데                 23  43.21  43.21    -2.70 -0.08  0.08 -3.01
# 7    8   키움                 23  37.40  37.40    -4.93  0.20 -0.45 -4.21
# 8    9   삼성                 23  36.03  36.03    -4.69  0.14  0.17 -2.62
# 9   10   한화                 23  33.74  33.74    -6.59 -0.02  0.09  1.25
#
#   Rep. Wins Pos. Wins WAA (투수)       Rep. Win (투수)       WAR (투수)
# ...

# %%
# 첫 번째 행을 헤더로 지정하고 데이터프레임을 새로 생성
team_2023_whole = team_df_whole_23.copy()
team_2023_whole.columns = team_2023_whole.columns.get_level_values(1)

# 첫 번째 행 제거
new_df = team_2023_whole.drop([0])

team_2023_whole
# Out:
#    Rank Team  Unnamed: 2_level_1    WAR   WAR▼     BT    SB    BR   Def  \
# 0     1   LG                  23  59.18  59.18  13.03 -1.30  0.19  0.58
# 1     2   KT                  23  52.24  52.24  -1.20  0.05  0.28  4.30
# 2     3   NC                  23  49.20  49.20   2.83 -0.07 -0.08  1.06
# 3     4  KIA                  23  47.45  47.45   4.89  0.49  0.18  2.74
# 4     5   두산                  23  45.49  45.49  -0.10  0.24 -0.17  1.34
# 5     6  SSG                  23  43.87  43.87  -0.45  0.35 -0.31 -1.44
# 6     7   롯데                  23  43.21  43.21  -2.70 -0.08  0.08 -3.01
# 7     8   키움                  23  37.40  37.40  -4.93  0.20 -0.45 -4.21
# 8     9   삼성                  23  36.03  36.03  -4.69  0.14  0.17 -2.62
# 9    10   한화                  23  33.74  33.74  -6.59 -0.02  0.09  1.25
#
#    Rep. Wins  Pos. Wins    GS    GR     GS    GR     GS    GR
# 0       2.39      -0.33  1.32  3.94  12.01  4.36  13.50  8.33
# ...
