# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://statiz.sporki.com/stats/?m=team&m2=batting&m3=default&so=WAR&ob=DESC&year=2021&sy=&ey=&te=&po=&lt=10100&reg=&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

team_table = soup.find_all('table')[1]  # 팀 테이블

team_df_batting_21 = pd.read_html(str(team_table))[0]  # 팀 데이터프레임

print("페이지의 팀 기록 데이터프레임:\n")

team_df_batting_21
# Out:
# 페이지의 팀 기록 데이터프레임:
#   Rank Team Unnamed: 2_level_0    정렬▼     G    PA   ePA    AB    R     H  ...  \
#   Rank Team Unnamed: 2_level_1    WAR     G    PA   ePA    AB    R     H  ...
# 0    1  SSG                 21  30.98  1929  5736  5673  4899  755  1278  ...
# 1    2   두산                 21  28.52  1978  5645  5590  4900  738  1314  ...
# 2    3   키움                 21  27.75  1827  5653  5606  4874  722  1262  ...
# 3    4   KT                 21  27.55  1999  5627  5542  4810  719  1276  ...
# 4    5   LG                 21  27.11  1961  5533  5471  4750  654  1188  ...
# 5    6   NC                 21  25.14  1909  5532  5462  4808  702  1254  ...
# 6    7   롯데                 21  23.53  1806  5726  5675  5009  727  1393  ...
# 7    8   삼성                 21  22.12  1816  5552  5493  4836  712  1292  ...
# 8    9   한화                 21  15.94  1603  5495  5432  4685  599  1111  ...
# 9   10  KIA                 21  14.12  1708  5577  5526  4831  568  1198  ...
#
# ...

# %%
# 첫 번째 행을 헤더로 지정하고 데이터프레임을 새로 생성
team_2021_batting = team_df_batting_21.copy()
team_2021_batting.columns = team_2021_batting.columns.get_level_values(1)

# 첫 번째 행 제거
new_df = team_2021_batting.drop([0])

team_2021_batting
# Out:
#    Rank Team  Unnamed: 2_level_1    WAR     G    PA   ePA    AB    R     H  \
# 0     1  SSG                  21  30.98  1929  5736  5673  4899  755  1278
# 1     2   두산                  21  28.52  1978  5645  5590  4900  738  1314
# 2     3   키움                  21  27.75  1827  5653  5606  4874  722  1262
# 3     4   KT                  21  27.55  1999  5627  5542  4810  719  1276
# 4     5   LG                  21  27.11  1961  5533  5471  4750  654  1188
# 5     6   NC                  21  25.14  1909  5532  5462  4808  702  1254
# 6     7   롯데                  21  23.53  1806  5726  5675  5009  727  1393
# 7     8   삼성                  21  22.12  1816  5552  5493  4836  712  1292
# 8     9   한화                  21  15.94  1603  5495  5432  4685  599  1111
# 9    10  KIA                  21  14.12  1708  5577  5526  4831  568  1198
#
#    ...  GDP  SH  SF    AVG    OBP    SLG    OPS  R/ePA   wRC+   WAR▼
# 0  ...  106  55  52  0.261  0.353  0.421  0.774  0.133  109.7  30.98
# ...
